# %% [markdown]
# <a href="https://colab.research.google.com/github/UhanWu/Invest-Atlanta/blob/main/InvestAtlanta_Group2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
df_excel = pd.read_excel('/content/Atlanta_Business_License_Records_2025.xlsx')

# Display the first 5 rows of the DataFrame
display(df_excel.head())
# Out:
#    license_number                  company_name company_dba  \
# 0  GBL-0121-00257           H & H Interiors LLC         NaN
# 1  GBL-0121-00258          One Lion Studios LLC         NaN
# 2  GBL-0121-00272         Destingkt Designs LLC         NaN
# 3  GBL-0121-00274                Mac Cigars LLC  J's Cigars
# 4  GBL-0121-00283  Essence of She Day Spa Salon         NaN
#
#                         license_classification             issued_date  \
# 0  Other Services except Public Administration 2025-01-07 13:21:16.143
# 1  Other Services except Public Administration 2025-02-16 18:39:21.153
# 2  Other Services except Public Administration 2025-03-04 23:04:53.980
# 3                                 Retail Trade 2025-02-25 23:09:11.497
# 4  Other Services except Public Administration 2025-01-09 19:04:30.857
#
#    naics_code                naics_name predirection          address_line1  \
# 0    541410.0  Interior Design Services           NE          2652 Forrest
# ...

# %%
import pandas as pd
df_excel = pd.read_excel('/content/Aglanta_FFA_2025_ATL_Only.shx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2557728273.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df_excel = pd.read_excel('/content/Aglanta_FFA_2025_ATL_Only.shx')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import geopandas as gpd

# Read a common shapefile
shapefile_path = '/Aglanta_FFA_2025_ATL_Only.shp'
gdf = gpd.read_file(shapefile_path)

# Read a GeoJSON file
geojson_path = 'path/to/your/data.geojson'
gdf_json = gpd.read_file(geojson_path)

# Read from a ZIP file directly
zip_path = 'zip:///path/to/your/data.zip'
gdf_zip = gpd.read_file(zip_path)

# Display the first few rows and confirm it's a GeoDataFrame
print(gdf.head())
print(type(gdf))

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt


# Use the Colab internal path, not your Mac path
file_path = '/content/Atlanta_Business_License_Records_2025.xlsx'

# Load the file
df_excel = pd.read_excel(file_path)

# Show the results
print(df_excel.head())
# Out:
#    license_number                  company_name company_dba  \
# 0  GBL-0121-00257           H & H Interiors LLC         NaN
# 1  GBL-0121-00258          One Lion Studios LLC         NaN
# 2  GBL-0121-00272         Destingkt Designs LLC         NaN
# 3  GBL-0121-00274                Mac Cigars LLC  J's Cigars
# 4  GBL-0121-00283  Essence of She Day Spa Salon         NaN
#
#                         license_classification             issued_date  \
# 0  Other Services except Public Administration 2025-01-07 13:21:16.143
# 1  Other Services except Public Administration 2025-02-16 18:39:21.153
# 2  Other Services except Public Administration 2025-03-04 23:04:53.980
# 3                                 Retail Trade 2025-02-25 23:09:11.497
# 4  Other Services except Public Administration 2025-01-09 19:04:30.857
#
#    naics_code                naics_name predirection          address_line1  \
# 0    541410.0  Interior Design Services           NE          2652 Forrest
# ...
